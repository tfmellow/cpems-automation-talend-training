# %%
import pandas as pd

# %% [markdown]
# ## **CASECN**

# %% [markdown]
# ### CASECN [Mapped OCC Data]

# %%
df_casecn_mapped = pd.read_csv('talend_output/CPEMS_FRLC_CASECN_OCC_20260125_MappedOCC.csv')

casecn_mapped_cols = ['Id', 
               'Resource_ID',
               'Trading_Hour',
               'Reasons', 
               'Date_From', 
               'Date_To',
               'Brief_Description', 
               'Attachments',
               'Registered_Capacity',
               'Offered_Capacity', 
               'Total_Offered_Capacity', 
               'Seasonal_Max_Capability',
               'Has_Outage'
]

df_casecn_mapped[casecn_mapped_cols]

# %% [markdown]
# ### CASECN [Tagged OCC Data]

# %%
df_casecn_tagged = pd.read_csv('talend_output/CPEMS_FRLC_CASECN_OCC_20260125_TaggedOCC.csv')
casecn_tagged_cols = ['Id', 
               'Resource_ID',
               'Trading_Hour',
               'Reasons', 
               'Date_From', 
               'Date_To',
               'Brief_Description', 
               'File',
               'Registered_Capacity', 
               'Offered_Capacity', 
               'Total_Offered_Capacity', 
               'Seasonal_Max_Capability',
               'Has_Outage'
]

# pd.set_option('display.max_colwidth', 50)
pd.set_option('display.max_colwidth', None)

df_casecn_tagged[casecn_tagged_cols]
# df_casecn_tagged[df_casecn_tagged['ID'] == 17835178][casecn_tagged_cols]

# %% [markdown]
# ### CASECN [Submitted Data]

# %%
df_casecn = pd.read_csv('talend_output/CPEMS_FRLC_CASECN_OCC_20260125_SUBMIT.csv')

casecn_cols = ['Id', 
               'Resource_ID',
               'Trading_Hour',
               'Reasons', 
               'Date_From', 
               'Date_To',
               'Brief_Description', 
               'File'
]

df_casecn[casecn_cols]

# %% [markdown]
# ## **PNTBNG**

# %% [markdown]
# ### PNTBNG [Mappedd OCC Data]

# %%
df_pntbng_mapped = pd.read_csv('talend_output/CPEMS_FGHPC_PNTBNG_OCC_20260127_MappedOCC.csv')
pntbng_mapped_cols = ['Id', 
               'Resource_ID',
               'Trading_Hour',
               'Reasons', 
               'Date_From', 
               'Date_To',
               'Brief_Description', 
               'Attachments',
               'Registered_Capacity', 
               'Offered_Capacity', 
               'IDR', 
               'Has_Outage'
]

df_pntbng_mapped[pntbng_mapped_cols]

# %% [markdown]
# ### PNTBNG [Tagged OCC Data]

# %%
df_pntbng_tagged = pd.read_csv('talend_output/CPEMS_FGHPC_PNTBNG_OCC_20260127_TaggedOCC.csv')
pntbng_tagged_cols = ['Id', 
               'Resource_ID',
               'Trading_Hour',
               'Reasons', 
               'Date_From', 
               'Date_To',
               'Brief_Description', 
               'File',
               'Registered_Capacity', 
               'Offered_Capacity', 
               'IDR', 
               'Has_Outage'
]

# pd.set_option('display.max_colwidth', 50)
pd.set_option('display.max_colwidth', None)

df_pntbng_tagged[pntbng_tagged_cols]

# df_pntbng_tagged[df_pntbng_tagged['Resource_ID'] == '01MASIWA_G01'][pntbng_tagged_cols]
# df_pntbng_tagged[df_pntbng_tagged['Resource_ID'] == '01PNTBNG_U02'][pntbng_tagged_cols]

# df_pntbng_tagged[df_pntbng_tagged['Id'] == 17860849]['Brief_Description']

# %% [markdown]
# ### PNTBNG [Submitted Data]

# %%
df_pntbng = pd.read_csv('talend_output/CPEMS_FGHPC_PNTBNG_OCC_20260127_SUBMIT.csv')

pntbng_cols = ['Id', 
               'Resource_ID',
               'Trading_Hour',
               'Reasons', 
               'Date_From', 
               'Date_To',
               'Brief_Description', 
               'File'
]

df_pntbng[pntbng_cols]
